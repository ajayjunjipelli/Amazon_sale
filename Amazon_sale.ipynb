# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/aadhi/OneDrive/Desktop/Data_analyst/Datasets/Amazon_Sale.csv")
# Out:
# C:\Users\aadhi\AppData\Local\Temp\ipykernel_24172\1603605743.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("C:/Users/aadhi/OneDrive/Desktop/Data_analyst/Datasets/Amazon_Sale.csv")

# %%
df
# Out:
#          index             Order_ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
category_list=['status','fulfillment','Sales Channel','Category','Courier Status','currency,''ship-city','ship-state','ship-country','Unnamed: 22']

# %%
df.dtypes
# Out:
# index                   int64
# Order_ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Style                  object
# SKU                    object
# Category               object
# Size                   object
# ASIN                   object
# Courier_Status         object
# Qty                     int64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# ship-country           object
# promotion-ids          object
# B2B                      bool
# fulfilled-by           object
# Unnamed: 22            object
# dtype: object

# %%
df
# Out:
#          index             Order_ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df.head(5)
# Out:
#    index             Order_ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
df.isnull().sum()
# Out:
# index                     0
# Order_ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier_Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
 df['Courier_Status']=df['Courier_Status'].fillna(df['Courier_Status'].mode()[0])

# %%
 df['currency']=df['currency'].fillna(df['currency'].mode()[0])

# %%
 df['fulfilled-by']=df['fulfilled-by'].fillna(df['fulfilled-by'].mode()[0])

# %%
 df['promotion-ids']=df['promotion-ids'].fillna(df['promotion-ids'].mode()[0])

# %%
 df['Amount']=df['Amount'].fillna(df['Amount'].mode()[0])

# %%
 df['ship-city']=df['ship-city'].fillna(df['ship-city'].mode()[0])

# %%
 df['ship-state']=df['ship-state'].fillna(df['ship-state'].mode()[0])

# %%
 df['ship-country']=df['ship-country'].fillna(df['ship-country'].mode()[0])

# %%
 df['ship-postal-code']=df['ship-postal-code'].fillna(df['ship-postal-code'].mode()[0])

# %%
 df['Unnamed: 22']=df['Unnamed: 22'].fillna(df['Unnamed: 22'].mode()[0])
# Out:
# C:\Users\aadhi\AppData\Local\Temp\ipykernel_24172\2442311523.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Unnamed: 22']=df['Unnamed: 22'].fillna(df['Unnamed: 22'].mode()[0])

# %%
df.isnull().sum()
# Out:
# index                 0
# Order_ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Style                 0
# SKU                   0
# Category              0
# Size                  0
# ASIN                  0
# Courier_Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# promotion-ids         0
# B2B                   0
# fulfilled-by          0
# Unnamed: 22           0
# dtype: int64
